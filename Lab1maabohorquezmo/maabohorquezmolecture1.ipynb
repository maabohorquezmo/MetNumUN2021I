# %% [markdown]
# #Introduction to the Research Environment
#
# The research environment is powered by IPython notebooks, which allow one to perform a great deal of data analysis and statistical validation. We'll demonstrate a few simple techniques here.

# %% [markdown]
# ##Code Cells vs. Text Cells
#
# As you can see, each cell can be either code or text. To select between them, choose from the 'Cell Type' dropdown menu on the top left.

# %% [markdown]
# ##Executing a Command
#
# A code cell will be evaluated when you press play, or when you press the shortcut, shift-enter. Evaluating a cell evaluates each line of code in sequence, and prints the results of the last line below the cell.

# %%
7 + 2
# Out:
# 9

# %% [markdown]
# Ejemplo Propio

# %%
9+6
# Out:
# 15

# %% [markdown]
# Sometimes there is no result to be printed, as is the case with assignment.

# %%
X = 2

# %% [markdown]
# ejemplo

# %%
z = 6

# %% [markdown]
# Remember that only the result from the last line is printed.

# %%
3 + 6
8 + 5
# Out:
# 13

# %% [markdown]
# ejemplo

# %%
6+8
5+1
# Out:
# 6

# %% [markdown]
# However, you can print whichever lines you want using the `print` statement.

# %%
print (1 + 5)
6 + 2
# Out:
# 6
# 8

# %% [markdown]
# ejemplo

# %%
print (7 + 8)
6 + 1
# Out:
# 15
# 7

# %% [markdown]
# ##Knowing When a Cell is Running
#
# While a cell is running, a `[*]` will display on the left. When a cell has yet to be executed, `[ ]` will display. When it has been run, a number will display indicating the order in which it was run during the execution of the notebook `[5]`. Try on this cell and note it happening.

# %%
#Take some time to run something
c = 7
for i in range(10000000):
    c = c + i
c
# Out:
# 49999995000007

# %% [markdown]
# ejemplo

# %%
#Take some time to run something
c = 4
for i in range(100000000):
    c = c + i
c
# Out:
# 4999999950000004

# %% [markdown]
# ##Importing Libraries
#
# The vast majority of the time, you'll want to use functions from pre-built libraries. You can't import every library on Quantopian due to security issues, but you can import most of the common scientific ones. Here I import numpy and pandas, the two most common and useful libraries in quant finance. I recommend copying this import statement to every new notebook.
#
# Notice that you can rename libraries to whatever you want after importing. The `as` statement allows this. Here we use `np` and `pd` as aliases for `numpy` and `pandas`. This is a very common aliasing and will be found in most code snippets around the web. The point behind this is to allow you to type fewer characters when you are frequently accessing these libraries.

# %%
import numpy as num
import pandas as pand

# This is a plotting library for pretty pictures.
import matplotlib.pyplot as mate

# %% [markdown]
# ##Tab Autocomplete
#
# Pressing tab will give you a list of IPython's best guesses for what you might want to type next. This is incredibly valuable and will save you a lot of time. If there is only one possible option for what you could type next, IPython will fill that in for you. Try pressing tab very frequently, it will seldom fill in anything you don't want, as if there is ambiguity a list will be shown. This is a great way to see what functions are available in a library.
#
# Try placing your cursor after the `.` and pressing tab.

# %%
num.random.triangular
# Out:
# <function RandomState.triangular>

# %% [markdown]
# ##Getting Documentation Help
#
# Placing a question mark after a function and executing that line of code will give you the documentation IPython has for that function. It's often best to do this in a new cell, as you avoid re-executing other code and running into bugs.

# %%
num.random.normal?

# %% [markdown]
# ##Sampling
#
# We'll sample some random data using a function from `numpy`.

# %%
# Sample 100 points with a mean of 0 and an std of 1. This is a standard normal distribution.
X = num.random.normal(0, 1, 1000)
print (X)
# Out:
# [-1.22668936e+00 -7.38638841e-03  1.79599355e+00 -2.06448254e+00
#   1.17775383e+00 -3.08173340e-01  6.39293639e-02  1.26014792e+00
#  -3.79956944e-01  4.79405483e-01  2.62345342e+00  7.37865341e-01
#   6.51451624e-01  1.21246908e+00  4.99896137e-01 -5.16801687e-01
#   4.16943610e-01 -5.90534914e-01  8.05406124e-01 -1.78464490e-01
#  -4.24686841e-01  9.38069584e-01  3.22609907e-02 -1.48679660e+00
#   2.35261329e+00  6.48078788e-01  1.01708568e+00  1.46406246e+00
#  -2.21204111e-01 -4.88125194e-01 -8.01425306e-01  3.93092549e-01
#  -4.80576473e-01  2.40348339e-01 -7.40110391e-01  7.63025518e-01
#  -1.62867927e+00 -2.02901500e+00  1.08436435e+00  1.02230537e+00
#  -5.30364586e-01 -4.98178632e-01  1.87449415e+00 -3.06545954e-01
#   1.59481784e+00 -5.74778407e-01  8.81708828e-01 -1.46204335e+00
#  -9.00357624e-01 -2.18267876e+00  7.48432287e-01  4.40585045e-01
#  -1.31482413e+00  6.69793434e-01  2.07724785e-01 -2.25349949e-01
#   4.96785758e-01 -5.95315760e-01  7.67971807e-01  4.24353177e-01
#  -9.12164523e-01  1.62504918e-01  1.98643005e+00  8.76402197e-01
#   6.57127868e-01  4.12053833e-01  5.01162386e-02  9.84829370e-01
#   2.29693498e-01  5.81459187e-01 -1.60141572e+00  2.69128480e-01
#   5.44217481e-01 -1.20828866e+00  1.57399988e-01 -8.53820073e-01
#   1.79436756e+00  7.72382675e-01 -8.90994109e-01 -1.03684988e+00
#  -9.45063069e-01 -8.03222147e-01 -7.53089585e-01  1.24346850e+00
#   5.81247240e-03  1.44198254e+00  3.10430899e-01 -5.08740127e-02
#  -4.03356759e-01 -5.21288738e-01  4.13507887e-02  5.80892523e-01
#  -1.69720308e-02  3.95460859e-01  3.85065463e-01  1.29440617e+00
#  -2.26505224e-01  7.18759523e-01 -1.19218203e+00  7.11566999e-01
#  -1.34220908e+00 -2.20096107e-01 -6.94622714e-02  1.76590388e+00
#   4.05113417e-01 -1.13474560e-01 -1.57931580e+00 -1.98197685e-01
#   1.45450905e+00 -9.59334480e-01  4.20190411e-01  2.30385994e+00
#  -4.04932133e-01  1.51048076e+00 -1.06243017e-01  1.10623063e+00
#   7.73326235e-01  5.72287975e-01  2.64008610e+00 -4.67512435e-01
#  -1.44819517e+00  4.59497130e-01  1.18182123e-01  1.26073606e+00
#  -8.41055206e-01  2.40600045e+00  1.49402569e-01  7.25109727e-01
#   1.13664248e+00  3.69372418e-02 -4.94146619e-01 -1.54500937e+00
#  -1.00468851e+00  8.34448389e-02  1.18810848e+00 -5.51257255e-01
#   2.08807016e+00 -1.45520593e+00 -4.03013034e-01  8.26159422e-01
#   8.79078292e-01  2.36357771e-01 -1.96405809e+00 -4.73188046e-02
#  -3.49729538e-01 -7.51692862e-01  1.04898328e+00 -1.52894378e-01
#  -3.57891062e-01 -8.62079421e-01 -1.56121504e+00 -1.69899142e+00
#  -1.17222548e+00  6.98405045e-01  5.08252634e-02  1.25259029e+00
#   4.33943746e-01 -7.35306144e-01 -5.09441818e-01 -1.43457775e+00
#   2.20330579e-01 -5.86452096e-01 -7.34637254e-01  1.03637498e-01
#   1.02573952e+00 -2.23026604e-01 -3.94672890e-01  2.25526602e-01
#  -1.73759494e+00 -1.17716798e-01 -1.21687579e+00  2.34768172e-01
#  -2.60473075e+00 -1.56045845e+00 -5.60181379e-01 -3.11393600e-01
#   2.48211301e+00 -2.55186587e-01 -9.93390599e-02 -1.49219601e+00
#   2.32636046e+00 -3.57766689e-01 -1.17740464e-01 -5.17218634e-02
#   5.07774848e-01 -7.30242172e-01 -1.77595260e+00  9.36399980e-03
#   9.31283545e-01 -8.45940962e-01  1.06343816e+00  7.02480940e-01
#  -3.64434359e-01  7.86119489e-01  2.19899991e+00  6.51293398e-01
#  -6.05163615e-01 -6.96186207e-01  4.58503968e-01  9.42575904e-01
#  -1.64609001e-01 -1.04161055e-01 -5.45603415e-01  3.37156924e-01
#  -4.58205477e-01 -8.76105592e-01  3.90097157e-01  5.15347637e-01
#  -2.27474305e-01 -1.79437673e+00 -1.88752878e-01  4.55092386e-01
#   2.47817994e-01 -1.02006716e+00 -9.51224825e-01  7.89286048e-01
#  -4.91971869e-01  1.70484694e+00 -2.81797026e+00  3.96066865e-01
#  -1.03743235e-02  5.10468121e-01  2.10715632e+00  1.44353182e+00
#   1.26561397e+00  8.50434896e-02  5.60253540e-01  1.07420088e-01
#   1.06866987e-01 -2.36957124e+00 -1.51416568e+00 -1.35766201e+00
#   4.82237873e-01  1.98600584e-01 -1.89850084e+00 -2.64766804e-01
#  -1.35976289e+00  2.87339075e-03 -1.36442776e+00 -4.01755263e-01
#  -8.32284546e-01 -9.43631902e-01  5.84104128e-01  5.65559588e-01
#   1.49675125e-01  6.65173288e-01  1.75472133e+00  3.61713007e-01
#   9.91092774e-01 -2.94099941e-01 -8.10912725e-01  2.11440493e-01
#  -7.44348975e-01 -5.29075293e-01  6.93604045e-01 -6.12457883e-01
#  -1.73885134e+00  3.01577373e-01  1.93573455e+00  2.08918852e+00
#   5.31603711e-01 -1.10533872e+00  1.92476632e+00 -1.00458502e-01
#  -1.36366735e-01  2.72687062e+00 -1.86404790e+00 -4.97611572e-01
#   1.68479595e+00 -4.37333481e-01  1.44842127e-01 -5.38353140e-01
#   1.34834635e+00 -3.50718069e-01 -6.09927425e-01 -3.72668830e-01
#  -2.49098055e+00  1.24715713e+00  1.44437531e+00  7.68065918e-01
#   1.51370925e+00 -1.18085284e-02 -1.78916500e+00 -1.47981024e+00
#   1.30160807e-01  9.54492255e-02 -9.23399246e-01 -1.62140252e+00
#  -7.35767208e-01  3.07866152e-01 -8.61723342e-02 -6.69054262e-01
#  -9.31562597e-01  1.25894040e+00 -1.43686840e+00 -1.16454385e+00
#   3.50298988e-01 -1.44521234e+00 -4.48873873e-01 -3.79344405e-01
#  -6.00701953e-01  7.42967395e-01  7.33042225e-01 -5.27927220e-01
#   1.15486007e+00 -7.16177362e-02  6.12105448e-01 -5.85092738e-01
#  -3.79257371e-01 -1.39744754e+00  7.88163913e-01 -5.53718968e-01
#  -1.38001542e-01 -2.53140646e-01 -1.93904970e+00  1.58940063e+00
#  -1.45321258e+00  1.42361682e+00 -3.67919686e-01 -1.59427261e+00
#  -1.89990305e+00  3.25366938e-01  1.41804089e+00  1.61765346e+00
#   5.70461023e-01 -3.64812999e-02  2.93437365e+00  4.86024962e-01
#  -5.88348063e-02 -3.94395243e-01  1.34005570e+00 -1.44622926e-01
#  -1.42550056e+00 -4.70061240e-01  4.50923794e-01 -1.22720802e+00
#   1.21061164e+00 -3.96121675e-01  7.78657931e-01 -2.51848079e-01
#  -1.03304404e+00 -9.62805049e-01 -4.39652672e-01 -1.21289211e-01
#  -3.45994335e-01  6.35567520e-01  8.50393490e-01 -1.13745784e+00
#   6.98013081e-01 -1.31474869e+00  7.64038128e-02 -1.23117315e-01
#  -1.50163928e-01 -1.91879600e+00 -5.95592201e-02 -1.94277283e-01
#  -9.48135836e-01 -1.69257019e+00 -2.82081291e-01 -6.51356271e-01
#  -2.62520875e+00  9.39731545e-01 -1.07596388e+00 -1.41504401e-01
#   2.86702868e-01 -9.56605355e-01 -1.43530419e+00 -2.94774430e-01
#  -7.13742981e-01  1.26912015e+00  3.27589031e-02 -8.75602802e-01
#  -1.34563752e+00 -2.54322247e-01 -1.97174789e+00 -1.34986770e-01
#  -1.85862714e-01  2.53310195e-01 -9.11871603e-01  1.63075627e+00
#  -2.68518312e+00 -9.60871395e-01 -3.91972775e-01  2.71080512e-01
#   2.19034996e-01  6.71807683e-01  5.51865839e-01 -3.43661180e-01
#  -6.29616327e-01  7.83908970e-01 -1.04092822e+00 -4.73308407e-01
#   1.24117066e-01 -1.09873098e+00 -5.65542161e-01  8.83403546e-01
#   3.57566618e-01  5.42910189e-01  2.33024042e-01 -2.51380329e+00
#   9.11102389e-01 -7.21251315e-01 -8.93460835e-02  1.93663397e+00
#  -2.70849381e-01 -4.31449983e-01 -4.50830039e-01 -1.38309405e-01
#   3.33620952e-02 -4.20200828e-03  9.15401787e-01  3.39637906e-01
#   5.07364485e-01  9.51759284e-01  7.67647613e-02  1.62371194e+00
#  -1.60502670e-01  1.33454617e-01 -3.55544819e-01  4.15515875e-02
#   2.14455548e-01 -1.25771212e+00  3.04574295e+00  3.44907156e-01
#  -1.95217940e-01  7.13114535e-01  4.68894293e-01  5.12931936e-02
#   9.83904603e-01 -1.36011460e-01 -2.02552860e+00 -1.87297933e-01
#  -2.17356297e+00 -2.01222660e+00 -8.60279957e-01 -2.64338100e-01
#   1.88767780e-01 -1.15357955e-01 -2.25326564e-01 -7.26187373e-01
#   4.39692896e-01  9.55506878e-01  7.61460566e-01  1.39468254e+00
#  -5.57822373e-01  1.08764201e+00 -4.62676784e-01 -9.20592678e-01
#  -1.08799556e+00  5.52095108e-01 -1.32062729e+00  8.22631118e-01
#   1.00789410e+00  5.08818903e-01  5.49245634e-01  5.47744694e-01
#   8.36468029e-02 -1.08030975e+00 -1.06527423e+00 -1.18126379e+00
#   1.48683194e+00  7.51846092e-01  2.45428650e-01 -6.17816875e-01
#   5.11560371e-01  2.06260873e-01 -8.72044331e-02  1.65291033e+00
#  -1.13366992e+00  1.46868041e+00  1.05267368e+00  3.83958984e-01
#  -4.99864197e-01 -3.86527571e-01 -9.07588484e-02 -7.44501730e-01
#  -8.94523390e-02 -2.42592144e-01 -2.20360411e-01  1.20795996e-01
#  -1.32869543e-01  6.77463488e-01  4.34367570e-01 -1.44528845e+00
#   2.04343441e+00 -2.03914274e+00  2.30151593e-01  1.49202361e+00
#  -8.83562639e-01  1.15078293e+00 -2.53248005e-01  5.79163648e-01
#  -1.00266228e+00 -7.00803667e-01  8.28154533e-01  1.18764003e-01
#   1.09602718e+00 -5.26170569e-01 -1.60494008e+00  5.40466854e-01
#   2.07674773e-01 -1.20408602e+00 -1.13882207e+00 -4.05710886e-01
#  -2.38771086e-01 -1.24852591e+00 -1.01969143e+00 -6.78206343e-01
#  -2.16275772e-01  5.06657509e-01 -4.07719169e-01 -1.66240010e-01
#  -5.20444987e-01  1.58895397e+00  1.45753805e+00  5.54942238e-01
#   8.27350597e-01  5.10555880e-01  1.07629310e+00 -2.41046797e-01
#   7.67013748e-01 -1.37240533e+00 -8.93658856e-01 -1.09791083e+00
#   7.94517344e-01  3.70723352e-01  3.45556223e-01 -1.84348786e-01
#  -3.58370860e-01 -8.00818752e-01  1.17839040e+00  6.72564893e-01
#   2.03246228e+00 -1.08803776e+00  8.41774047e-01  3.31268144e-01
#  -7.36465671e-01 -1.11774724e+00 -1.04601062e+00  2.90007642e-01
#  -1.19489112e+00 -2.32406818e-01  1.19742470e-01 -1.13637021e+00
#  -4.43168948e-01  5.57547859e-01 -7.97230269e-01 -6.65632580e-02
#   5.10286440e-01  8.00710064e-01  1.33753591e+00 -9.93171113e-01
#   7.07857279e-01  4.46156768e-01 -1.50684056e+00  4.77905898e-01
#  -9.18609924e-01 -2.08596766e-01 -7.85286965e-01 -2.71662498e-01
#   1.75254300e+00 -5.36609356e-01  7.55268672e-01  1.35397543e-01
#  -5.31948482e-01 -1.07560181e+00  1.96424192e-01  5.16912158e-01
#   2.63371461e-02  5.10795718e-01 -3.27918630e-01  6.11740796e-01
#  -7.94614216e-01  3.85826584e-01 -1.01744162e-01  2.04637537e+00
#   6.78189858e-01 -4.12602823e-01  1.45253402e-01  6.69408306e-01
#  -3.05737001e-01 -8.33194318e-01  7.84801821e-01 -2.56514609e-01
#  -1.09971533e+00  3.46194591e-01 -6.15865816e-01 -7.78399338e-01
#   5.09486462e-01  1.17013891e+00  1.31296372e+00  2.63820978e-03
#   6.88022160e-01  2.70446241e-01  5.16100793e-02  2.46260209e-01
#  -6.16703613e-01 -1.01484453e-01  1.11568272e+00 -2.17954196e+00
#  -1.12611219e+00 -4.43014352e-01  1.53769836e+00  1.44062771e-01
#   7.82178058e-01  1.24058627e+00 -3.91721740e-01 -1.00271049e+00
#   1.08085041e+00  5.77291694e-01 -1.07871034e+00 -1.99625119e-01
#  -1.98217116e+00 -1.22411282e+00 -5.45259161e-01 -9.92936794e-02
#   5.23464376e-01 -5.77808649e-01  5.83709213e-01 -2.64903712e-01
#   3.95575240e-01 -1.97234350e+00 -4.04630913e-01 -5.71645590e-01
#   1.57441667e+00 -1.13124349e+00 -9.93022896e-01 -8.27131858e-01
#   1.28891184e+00 -3.94870216e-01  3.83998637e-01 -9.42536719e-01
#   9.40327319e-01 -2.02985911e-01  8.82987851e-01  1.08379763e+00
#  -6.74298174e-01  7.77020012e-01  6.47035186e-01 -9.59568236e-01
#   9.65508656e-02  1.17597706e+00  8.37209484e-02  1.32215782e+00
#   3.86026107e-01  4.54858701e-01 -1.35761755e+00  1.26776496e+00
#  -1.88351215e+00 -2.44317399e+00 -9.28372349e-01  5.16402720e-02
#   1.02210518e+00  6.01917109e-01 -7.92626775e-01  5.96564856e-01
#  -7.11389798e-01 -5.08585278e-01  3.37994111e-01 -1.37723940e+00
#  -1.49840209e+00 -4.75478854e-01 -1.74457257e-02 -6.01579207e-01
#   8.73051642e-01 -4.36344889e-01  4.53753588e-01 -7.85328968e-01
#  -1.82884420e+00  9.62957571e-02 -1.23477042e-01  7.98763902e-01
#  -3.58276090e-03 -2.82059559e-01  1.95525353e-01  1.48618254e+00
#  -1.64776323e+00 -1.67243859e+00 -1.73273384e+00  1.47991866e+00
#  -2.43461893e-01 -6.84014707e-01 -8.88526933e-01  8.45643477e-04
#   1.53151606e+00  2.23462024e+00  1.16644644e-01 -8.67666399e-01
#  -8.19189788e-01  6.87729447e-01 -1.20924841e-01  1.23514095e+00
#   6.63875551e-01 -1.08836267e+00  6.35802104e-01 -1.41483780e+00
#  -1.20657098e+00  9.67214434e-02  1.05812316e-01  1.92284215e+00
#   9.91934176e-01  9.32645516e-01  1.14377443e+00  1.75101981e-01
#  -6.52112286e-02 -1.61453863e-01 -5.50747678e-01  9.57029626e-01
#  -4.38627087e-01 -3.05386176e-01  2.87958505e-01 -4.37740460e-01
#   3.59048043e-01  2.17171602e+00  8.27333885e-01 -6.44892512e-01
#  -3.65305556e-01 -2.66017746e-01 -1.88716810e-01 -5.58891687e-01
#  -4.47518411e-02  2.62338678e-01  1.68965817e+00 -5.43822336e-01
#   1.30072527e+00  1.07656349e+00 -7.41323367e-01 -1.28147286e+00
#   4.21557022e-01  9.43351694e-01 -1.82051061e+00  2.29557807e-02
#  -7.10379562e-01  2.05745003e+00 -2.98950262e-01 -9.24852069e-01
#  -2.24076726e-01 -8.85440815e-01  9.67515001e-02 -1.21294268e+00
#  -2.30446659e+00 -1.52752497e+00  2.37054062e-01 -3.84147315e-01
#   1.27273643e+00 -2.88761659e-01  8.40737077e-02  3.26363972e+00
#   6.44888449e-01 -5.66220863e-01 -6.75508937e-01  8.95396007e-01
#   1.67221400e+00  2.24457180e+00 -9.63028547e-01 -6.98829407e-01
#  -1.19284306e+00 -1.07423167e+00 -2.13477596e+00  2.12120465e+00
#  -7.33124132e-02  4.12653314e-01 -1.00585614e-01 -1.44917397e+00
#  -1.47585274e+00 -1.91657958e-01  6.63295743e-01  6.41618944e-01
#   1.08934242e+00 -5.99349451e-01 -2.16669526e-01 -3.77746895e-03
#  -2.12534024e+00 -8.31674948e-01  2.31289494e-01  2.64916021e-01
#   2.14172436e+00  1.89500519e-01  1.89300007e+00  3.23522357e-01
#   5.95726059e-01 -4.74952253e-01  6.90126611e-01 -1.88680824e-01
#  -2.37140634e+00 -1.22875787e+00  1.62796690e+00 -8.14321291e-02
#  -2.34225160e+00  5.69970430e-02 -1.20317290e+00  8.43334771e-01
#   1.79851694e-01 -1.00448053e+00  2.24703000e-01 -9.76462470e-01
#  -1.86612484e+00  3.53410672e-02 -3.32710456e-01  4.38919707e-01
#   7.39469848e-01 -3.12644944e-01  1.05619333e+00 -8.37341621e-01
#  -1.53780324e+00  9.60932816e-01 -7.98197582e-01  2.27131517e+00
#   1.10522648e-01  1.88334910e+00 -3.59018753e-01  2.47545236e-01
#   3.56013141e-01 -8.02919072e-01  1.58941138e+00  6.07044607e-01
#   4.64292346e-01  1.44767850e-01 -2.00569116e-01 -3.22577130e-01
#   2.95546096e-01 -8.59356675e-02  1.98523792e+00  1.22460460e+00
#   5.12111630e-01 -1.21619771e+00  1.51289952e+00 -2.44709835e+00
#  -4.82894252e-01  9.47457995e-02  4.72713486e-01 -2.05703161e-01
#  -1.40493913e+00  6.36367643e-01 -1.74791109e+00  1.02485235e+00
#   4.68052483e-02 -1.64720676e+00 -1.35427188e+00 -7.83330806e-01
#   2.90646104e-01  5.67004975e-01 -4.57614602e-01  5.16921934e-01
#   7.41669130e-01 -5.10451638e-01 -1.19432014e+00  2.37126132e+00
#  -1.08126604e+00  8.59556453e-01 -1.09569398e+00  1.08193622e+00
#   9.87811543e-02  1.03500584e+00  9.44541162e-01 -1.19603565e+00
#   1.09693034e-02  7.61731908e-01  1.88941985e+00  6.02940086e-01
#  -5.42929954e-01 -7.40970775e-02 -1.40228815e-01 -1.05331472e+00
#   9.87711062e-01  9.07165391e-01  1.66238218e-01 -3.34351590e-01
#  -2.02775882e-01 -2.57657262e-01 -1.32575067e-01 -5.81854499e-01
#   1.76115351e-01 -1.49296736e+00  2.99188644e-01  6.89596731e-01
#  -1.02265969e+00 -5.41064704e-01 -1.31207992e+00  9.58975776e-02
#   7.86276848e-01 -3.57143780e-01  3.84440690e-01 -2.11691592e-01
#  -1.04504555e+00  2.65346383e-01 -3.59378044e-01  6.43799695e-02
#  -2.30394107e+00 -1.22641013e+00 -5.62860689e-01  2.07714799e+00
#   1.16436982e+00 -6.62914418e-01  1.11738523e+00 -8.20727659e-01
#  -6.44170274e-01 -3.42301574e-01 -6.32135976e-01  1.30765824e+00
#   1.44672748e+00 -1.20021552e+00 -1.03719948e+00  1.30549417e+00
#   1.61832135e+00 -1.48025861e+00  4.76520743e-01 -1.48377174e+00
#  -8.16781962e-01 -9.59455343e-02 -3.45647566e-01  5.35133428e-02
#   1.12439912e+00 -1.88807835e-01 -8.39281680e-01  3.81973195e-01
#  -1.46846620e+00 -3.04438124e-02 -7.55892568e-01 -5.02966868e-01
#   1.22089691e+00 -2.21808289e-01 -1.36126780e+00 -1.31562092e+00
#  -2.23551424e-01 -2.13001233e+00  2.16559322e-01  2.45882899e-01
#   2.46255297e+00 -5.96262514e-02  2.04288366e+00 -8.33719214e-02
#   6.81084744e-02  1.99941801e+00 -2.12605367e-01 -8.79402174e-01
#   1.22101683e+00  2.87841365e-01  8.26177056e-01  6.03167582e-01
#  -3.62755866e-01  1.45937232e+00  1.14277441e+00  8.06002822e-02
#   1.13965148e+00 -1.85507892e+00  1.66843385e+00  5.52851636e-01
#   3.26597476e-01 -8.32992620e-01  2.46242040e+00 -4.67189204e-02
#   1.06390278e+00  6.36900861e-01  1.77471297e+00 -7.81400944e-02
#  -2.89188255e-03 -4.26201778e-01 -6.23833654e-01  2.36366805e-01
#   5.97816757e-01  1.01860331e+00 -8.29064990e-01 -4.88269999e-01
#   7.83122508e-01  1.79153584e-02 -2.68414016e-01 -2.47693410e-01
#  -4.57612794e-01 -3.44293265e-01  5.76141271e-01 -9.56349546e-01
#  -2.80449892e+00 -4.82953393e-01  3.26513083e-02  9.76948538e-01
#  -3.64221719e-01  2.92116928e-02  5.52307466e-01 -2.73414428e-01
#  -1.00051315e+00 -6.89124317e-01  8.25318008e-01  1.32695535e-01
#   1.12980927e-01  1.01571979e+00  1.06155626e+00  1.91157607e-01
#  -5.20753557e-01 -7.89848016e-02 -9.49351215e-01  1.44466043e+00
#   4.23031734e-01  3.90289770e-01 -7.82831481e-01  1.90579102e+00
#  -2.00003462e-01 -6.58250020e-01  2.11620776e-01  1.11058327e+00]

# %% [markdown]
# Ejemplo

# %%
Y = num.random.normal(0, 1, 1000)
print (Y)
# Out:
# [-7.88234259e-01  6.01933026e-01  1.60683941e+00 -8.24447553e-01
#   7.06388625e-01  1.63268744e+00 -9.83542084e-01  6.84088100e-01
#  -7.68125933e-01  4.25619534e-01 -1.45068642e+00 -8.33105290e-01
#  -3.43452801e-01 -1.50242014e+00 -5.98537897e-01 -1.57008344e+00
#  -1.46758611e-01 -9.08777507e-01 -1.44586651e+00 -2.85905936e-01
#   9.09713053e-01  1.28819560e+00 -2.30995239e+00 -8.47875717e-01
#   5.20227355e-01  1.17875294e-01  3.17779143e+00  7.45059229e-01
#   2.69489172e-01  2.44481825e-01  3.40082907e-01  1.27951107e+00
#  -2.07398125e+00  4.68795573e-03 -5.07607957e-01 -1.23361829e+00
#   2.33057873e-01  9.55684849e-01  2.85464932e+00 -1.31219729e+00
#  -9.34000516e-01  5.59778385e-01  2.78047155e-01 -5.86213830e-01
#  -6.18036726e-01  2.55016000e-01 -9.66393059e-01  1.64480883e+00
#   8.16091608e-01  1.76434037e+00 -5.61353687e-01 -9.77445162e-01
#  -1.03438300e+00 -3.30265745e-01  1.46166183e+00  3.00507770e-02
#  -7.05593691e-01 -6.79288429e-01 -1.56215227e+00  1.18792938e+00
#  -6.49568763e-01 -8.10608031e-01 -2.42818294e-01  2.40755161e+00
#   5.90579572e-02 -4.09322092e-01  1.23762107e+00  1.03297294e+00
#   1.52974715e+00  1.87287467e+00 -1.23511364e+00  2.45593489e-01
#  -1.36885536e-01 -8.45954068e-01  7.51129556e-01  2.37061548e-01
#  -1.01805482e+00  7.67914081e-01  4.50827182e-01 -9.17603690e-01
#  -6.99215000e-01 -2.83273904e-01  1.55396406e+00 -9.01960725e-01
#  -9.52859973e-02  6.23385873e-01 -4.66950789e-02  1.53491354e+00
#   1.32777817e-01 -9.05652199e-01 -2.18271326e-01 -1.76444565e+00
#  -6.65437606e-01  8.25577737e-01 -1.26607601e+00 -1.35781115e+00
#  -3.42034138e-02 -5.11121959e-02  1.67150403e+00 -1.14143610e+00
#  -5.62992354e-01 -1.42544958e+00 -2.78362369e-01  1.19841342e+00
#   8.83742163e-02  2.79093394e-01 -3.21870507e-01 -9.92975357e-01
#  -5.84252024e-01 -8.47702275e-01  1.48861725e-01 -2.22018594e-02
#  -7.37404007e-01 -7.70169580e-01  9.83995275e-01  1.24907498e+00
#   1.44332589e+00 -2.02406985e+00 -5.01244439e-01  8.92368261e-01
#  -7.20930123e-01  8.72768963e-02  1.02114405e+00  2.79699203e-01
#   2.11602969e-01 -1.52848185e+00  9.13067582e-01  1.02475497e-02
#   1.24098946e+00 -1.31513581e+00  7.38112211e-01 -1.41633643e-01
#   5.43440657e-01  1.37240319e-01 -1.42986708e+00  6.06466586e-01
#   4.48433932e-01  4.29738110e-01 -1.29352747e+00  3.88452409e-01
#  -1.04468333e+00 -6.83881796e-01 -1.15453735e+00 -5.78083139e-01
#  -9.99209017e-01  8.45639722e-01  3.53620919e-01  1.14408622e+00
#   1.62771082e+00  3.70159389e-01 -1.01728296e+00 -9.31872310e-01
#   1.15096620e-02  2.00231305e+00 -2.68681735e-01 -7.19640815e-01
#   1.00489514e+00 -7.38434966e-01  4.35754144e-01  1.48231466e+00
#  -5.72770886e-01 -8.12456731e-01  1.95770069e-01 -1.05984052e+00
#  -1.28021472e+00 -4.08143299e-01  2.59150687e-01  1.27255541e+00
#   9.65660142e-01  3.92526571e-01  5.89460609e-01 -1.59905866e+00
#  -2.78857277e+00 -2.21635995e+00 -4.73740922e-01  1.46969895e+00
#   6.10310086e-01  1.34270789e+00 -1.13844320e+00  4.34035445e-01
#   6.81537048e-01  4.21386668e-01  3.75707864e-01  6.40498678e-01
#  -2.37333573e+00  1.00218992e+00 -1.21298817e+00 -1.51323496e+00
#  -5.54784687e-01 -1.45220424e+00  7.30713130e-01  9.91652842e-01
#   1.41023726e+00  8.64289778e-01 -4.44754301e-01 -2.19055146e+00
#   5.24765950e-01  3.92821228e-01  8.84976538e-01 -1.11564882e-01
#   8.76600976e-01  4.12386541e-01  3.43543134e-01  4.91892642e-01
#   9.10752782e-01 -6.67663473e-01 -8.85569939e-01  5.56477045e-01
#   5.27754814e-01  5.88287113e-01  1.34210966e-01  5.20790564e-01
#   6.09204438e-01 -1.61187385e+00 -4.21477760e-01  7.27940784e-01
#   1.93898776e-01  6.94399280e-01 -1.67205285e-01 -1.27507443e+00
#  -3.05434240e-01 -6.35034574e-01  4.18144902e-01  6.64920270e-01
#   8.42097461e-01  1.49761473e-01 -1.72711367e-01  1.58920851e+00
#  -3.48922458e-01  5.77741115e-02 -1.36315631e+00  2.70119288e-01
#  -6.04451404e-01 -8.39857194e-01  1.75465790e-01 -1.91017333e+00
#   1.11443298e+00 -2.25307467e-01 -5.28296231e-01 -3.46181573e-01
#  -1.37424875e+00 -2.39354718e+00  1.80629120e-01  8.41262266e-01
#   5.49306675e-01 -1.39033793e+00 -1.06508500e+00  9.46529115e-01
#  -4.05184425e-01 -1.19830600e-01  1.42369089e+00 -6.95879474e-01
#   7.79870358e-01 -4.30343225e-01 -4.65521254e-01  6.71073185e-01
#  -7.51719910e-01  1.18365371e+00  1.06451500e+00  1.11305739e+00
#   4.43549556e-01 -7.86165443e-01 -6.35319917e-01  1.96620955e-01
#  -6.57865539e-02 -9.84561821e-02  3.36342556e-01 -1.45567504e+00
#   7.86629433e-01 -4.00872194e-01 -5.12753940e-01  1.03227303e+00
#   3.39263653e-01  7.03615202e-01  9.35511545e-01 -8.82759060e-01
#   1.17093316e+00  1.26876431e-01 -6.15357901e-01  8.56428075e-01
#   6.82469068e-01 -1.13579943e+00 -7.10103592e-01 -1.14093199e+00
#   1.48053047e-02 -5.07944331e-01  6.16395004e-01  1.02185933e+00
#   2.47990064e-01  1.09704983e+00  7.71369442e-01  1.80830216e+00
#   2.98076780e-01  1.25774353e+00 -2.30241097e-01 -1.29413866e+00
#  -9.22931347e-01 -6.63973324e-01 -3.59700799e-01  4.40803467e-01
#  -8.66216590e-01  4.18410439e-02  1.11815414e+00 -8.96685971e-01
#  -3.50634637e-01  6.53062994e-01  9.48299632e-02  6.81099611e-01
#   2.26341229e-01 -1.10626545e+00  1.25171331e-01 -5.80462406e-01
#  -1.24576744e+00  8.89705456e-01 -1.09434726e+00 -1.32636010e+00
#   6.16460372e-01  4.46845380e-01 -9.55682656e-01 -8.22374812e-01
#  -2.37819916e-01 -9.26936056e-01  1.96627335e+00 -1.80637739e+00
#   1.04473545e+00  1.54253780e+00 -8.05425704e-01 -5.36695616e-01
#  -2.38136833e+00 -1.62076963e+00 -1.75863365e-01  5.08667029e-01
#  -1.82805878e+00  4.22974005e-01 -2.00857837e+00 -1.33764748e+00
#  -1.06401463e+00 -2.56963277e+00 -2.10144497e+00 -1.01105177e+00
#  -2.07364226e+00  4.98897882e-01  9.58338099e-02 -3.08911369e-01
#  -7.35776902e-02 -1.61822383e-01  8.20624156e-02 -5.31035493e-01
#   1.03506019e+00  8.26566960e-02 -8.52338004e-02 -4.41403441e-01
#  -5.71122230e-02  2.34589806e+00  2.30185850e+00 -2.37695539e-01
#  -1.22417520e+00  2.41125950e+00 -8.33708266e-01  3.26524066e-01
#   5.43704329e-01 -4.61688368e-02  2.08525807e+00 -1.83240469e-01
#  -9.05223329e-01  9.72225554e-03 -6.74794840e-01 -3.10266469e-01
#  -9.15233214e-01 -1.55276199e-02 -8.13062456e-01 -6.00616565e-01
#  -3.50828686e-01  2.32675785e+00  8.15535910e-01 -3.67340196e-01
#   2.32818817e+00  1.18496275e+00 -1.61131739e-01  8.00536370e-01
#  -6.34624336e-01 -5.27521241e-01  1.31661678e+00 -2.85078519e-01
#   6.76787608e-01  1.60550040e-01  1.79981784e-01 -3.79628317e-01
#  -2.84762831e-01  1.02752473e-01 -1.91627764e+00  6.82509625e-01
#   1.80328735e+00  5.33676640e-01  4.62254159e-01  4.92246618e-01
#  -4.00879855e-01  1.49539410e-01 -3.03046636e-01 -3.17936376e-01
#   1.49719378e-01  9.06256701e-01  6.87346364e-01  1.43334820e+00
#  -1.95997522e+00  9.88604182e-01  2.02571409e-01 -4.72479333e-01
#   1.12612083e-01  1.76048980e-02 -6.10708483e-01 -7.20658533e-01
#  -4.99217268e-01 -5.42306547e-02 -1.38064828e-01 -3.96958939e-01
#   6.51007444e-01 -1.67502715e+00 -1.40774173e+00  8.43709711e-01
#   1.67704720e+00 -2.52952899e-01  2.46936657e-01  1.01095150e+00
#  -5.89381030e-01 -1.50600833e+00  2.20455474e-01 -3.81281084e-01
#  -8.11050950e-02  1.06513236e+00  5.23425693e-01  3.86652797e-01
#  -1.72135589e+00 -7.62245692e-01 -2.34264715e-01 -1.34507865e+00
#  -5.39118938e-02  5.67549553e-01  1.13777135e+00  1.35243185e+00
#  -9.26544965e-01  4.35986518e-01  4.00377545e-01 -9.90956117e-01
#   1.48489948e+00 -4.57035824e-01 -1.36626199e+00 -6.95551562e-01
#   2.56509471e-01  1.38032949e+00 -1.54291711e+00  4.40606070e-01
#   6.75177935e-02  6.02303528e-01 -2.59448291e-01 -1.10029289e+00
#   9.11484721e-01  1.57650777e+00  2.32722488e+00  9.23935992e-01
#   2.49942813e-01  2.28076325e+00  9.14743991e-01 -1.21518408e+00
#   1.68902229e-01 -1.42675615e+00  4.58656570e-01 -3.82894542e-02
#   3.27536014e-01  1.27226891e+00 -6.63287607e-02  1.32236849e-01
#  -9.82949245e-01  8.43698339e-01 -9.13127691e-01  4.01294189e-01
#   1.27142741e-03  1.70186667e+00  2.59096577e-01  1.09339129e+00
#  -7.92985701e-01 -1.32153829e-01  1.30504808e+00  1.29548067e-01
#   1.35957942e+00 -2.05806822e+00 -9.43768220e-01 -1.07847846e+00
#  -8.51658206e-01 -9.36500962e-01  3.87491920e-01 -1.05770304e+00
#  -2.28388858e-02 -2.23253828e-01  1.93313958e+00 -9.81219140e-01
#   5.41497400e-01  6.55446840e-01 -4.82424642e-01 -6.45202359e-01
#  -5.56127023e-01 -5.26513902e-01  1.40699112e-01 -5.49596178e-01
#  -2.07881399e+00 -8.70610848e-01  4.07932148e-03 -1.43892018e+00
#  -1.40128978e+00  5.03058132e-01 -2.93549157e-02  3.96243902e-01
#  -7.00547332e-01 -3.86979210e-01  8.70157049e-01  1.49735055e+00
#  -8.98099183e-02  1.22846092e-01  3.53139842e-01  6.90033877e-02
#  -3.64273911e-01 -3.98688220e-01  9.14101817e-01 -2.21021026e-01
#  -1.25734332e+00  3.79702296e-01 -1.12053761e+00 -1.48567730e+00
#   8.44896312e-01 -1.55436333e+00 -7.29336924e-01 -4.91465853e-01
#   1.45170458e-01 -3.85766027e-01  5.58590350e-01  2.86302138e-01
#   1.90050018e+00  1.60391965e+00  1.77068243e-01  8.36064922e-01
#  -1.44273563e-01  1.28653384e+00  2.64227767e+00 -3.49696772e-01
#   2.36849477e-01 -2.92108768e-01  3.47460379e-01 -8.46548246e-02
#  -1.28292595e-01 -4.34352658e-01  6.72440215e-01  1.39030998e-01
#   2.58538901e-01 -2.20066568e-01  3.04760958e-02 -5.39995342e-01
#   7.34426676e-01 -7.51961974e-01 -8.44702435e-01  3.74450831e-01
#  -1.21602652e+00  9.81625760e-02  5.82658775e-02  4.75199437e-01
#   3.56093479e-01 -5.10173704e-02 -6.30853884e-01 -6.04280184e-02
#   4.89150021e-01  1.70926999e-01 -1.69401956e-01 -2.12657349e+00
#   5.40455914e-01 -1.32584072e+00 -2.35597639e-01 -3.07629963e-01
#   7.54890779e-01  2.18741980e-01 -1.21961814e+00 -1.23558441e-01
#  -1.45699391e-01 -3.65807257e-01  7.56639878e-01 -1.98742612e+00
#   1.33701247e-01  6.90220871e-01  2.92075685e-01  1.01563024e+00
#   1.22233860e+00 -1.01532385e+00 -1.33094697e-02 -2.61213196e-01
#  -1.50518715e+00 -6.88681974e-01  2.72281814e-01 -5.56863327e-01
#  -4.50891532e-01 -1.65178352e-01  1.46258916e+00 -8.13640340e-01
#   1.53780091e+00 -2.21933538e+00  8.31966192e-01  8.93488940e-01
#  -1.59321523e+00  2.51468968e-01  7.01131162e-01  4.17137443e-01
#  -5.46127517e-01 -2.34116255e-01  9.33014187e-01 -6.36697805e-01
#   3.72951878e-01  1.81732956e+00  5.08221717e-01  1.31683214e+00
#  -8.95338815e-03 -2.48606699e-02  2.16869648e+00  2.03409098e-01
#  -1.85295753e+00 -1.24269875e+00  1.93215170e+00 -3.95660108e-01
#   1.77215058e+00 -1.41436733e-01  4.64866677e-01 -1.02100243e+00
#  -4.34960584e-01 -7.47091678e-01  3.88029820e-01 -2.60211433e-01
#  -5.23528001e-01 -9.62281185e-01  1.16715522e+00 -3.57147942e-01
#   9.88526589e-02  8.30951252e-01  2.67337368e+00 -1.31691933e+00
#   1.22380045e+00 -4.45262214e-01 -5.02754566e-01  2.38164494e-01
#  -1.78843944e-01  5.19090856e-01 -6.83141375e-01  5.35233541e-01
#  -1.00561644e-01  3.90707512e-01  1.61213945e+00 -9.43734438e-01
#   2.02993593e-01 -6.24508509e-01  2.46253471e+00 -5.32902705e-01
#  -1.82886054e+00 -4.99875352e-01  8.33640932e-01  2.09195037e-01
#   5.21786165e-01  1.12521694e+00  1.28612978e+00 -1.26084718e-01
#   8.78881503e-01  6.32907486e-01 -8.07725817e-02  5.56316092e-01
#   4.70485728e-01 -7.05046290e-01  5.04521304e-01  2.18447552e+00
#  -4.26828320e-01 -5.54003439e-02  2.44744137e+00 -7.49865078e-01
#  -3.36655748e-02  1.62301378e-01 -1.47021403e+00 -4.12170061e-01
#   5.42569428e-01  1.03775822e+00  2.44064219e-01 -7.48749912e-01
#  -8.40283592e-01 -6.51178010e-02  5.07478389e-01 -3.85333567e-01
#   2.15897265e-01 -2.90405825e-01  1.17948207e+00  5.35384431e-01
#   4.28362681e-01 -1.71811182e+00 -1.77582371e+00 -5.03424084e-01
#   9.38620966e-03 -6.58844600e-01 -1.18827617e+00 -1.14178196e+00
#  -9.47911078e-02  1.16960094e+00  7.12009131e-01  1.04262701e-01
#   3.36154235e-01 -2.02257469e+00  1.22129739e+00  1.62184383e-01
#   9.77794401e-01 -4.78805387e-01  2.38512195e-02  4.97337060e-01
#  -9.84584236e-01  9.68436722e-02 -4.73082660e-01  8.48901365e-02
#  -2.26807307e-01  2.15963998e+00 -7.43355882e-01 -1.92631190e+00
#   3.65154847e-01  2.38874775e-01  2.64405143e-01  1.05300030e-03
#  -9.45661744e-01  7.97491465e-01  1.39652991e+00  3.15355839e-01
#  -1.09573449e+00  1.36601211e+00 -5.32603071e-01 -9.39152383e-01
#   1.17674347e+00  8.62426300e-01  3.13494307e-01 -8.21789070e-01
#   5.46382537e-01 -1.33362357e+00  1.87609862e-01  3.94918025e-01
#  -1.47826598e-02 -3.87775715e-01 -2.75046992e-01 -7.83027351e-01
#   2.21269655e-03 -1.68853941e+00 -3.28508895e-01  1.07320784e+00
#  -9.69735440e-01 -2.18409117e-01  6.55592015e-01  5.19739308e-01
#   1.27040689e+00 -1.82624276e+00 -3.96228148e-01 -1.38834795e-01
#   1.21231383e+00  6.32580527e-01 -8.76132575e-02 -7.54847234e-01
#  -2.76043579e-02  2.00636207e-01 -8.76304412e-01 -1.94223262e+00
#  -4.64916502e-01 -2.14012893e-01 -3.79599265e-01  8.68414413e-02
#   1.61329448e+00  5.39286490e-02 -1.05757777e+00 -1.16932108e+00
#  -1.96887632e-01 -3.57517267e-02  2.06734944e-01 -2.83535756e-04
#   6.78942126e-01 -2.35815887e-01 -5.92680229e-01  3.09625874e-01
#   6.85272880e-01 -1.55193575e-01  7.50441763e-01 -1.34829155e+00
#  -2.41277328e-02 -3.07467980e-01  9.19766832e-01 -2.44945650e-01
#  -4.59848287e-01  1.81447541e-01 -9.76437895e-01 -3.00365169e-01
#  -1.58558949e+00  6.43000528e-01 -1.18700092e+00 -6.58346154e-01
#   1.19735765e+00  1.88477141e-01  7.50770706e-02 -3.79768347e-01
#   7.98354844e-01  1.82532636e+00  1.24984693e+00  7.70988022e-01
#  -1.01279624e+00 -2.34614268e-01  5.83715184e-01  2.74455632e-01
#   1.38190565e+00  8.90404450e-01  2.56544280e-01  3.56525334e-01
#   6.16801175e-01  8.89018134e-01  9.78422877e-01  2.53740071e+00
#   9.94673631e-01  2.91816404e-01  1.77357785e+00  1.07275242e+00
#  -6.75884868e-01 -1.04364757e+00  4.33767923e-01 -1.68538074e+00
#   7.89093709e-01  1.93997415e+00  2.10107438e+00  4.88886589e-01
#   2.01128930e+00 -6.94082661e-01  6.60784964e-01  1.09000812e+00
#  -2.62613020e-01 -1.94428419e+00 -1.39110429e+00 -1.03798705e-01
#  -2.80436079e-02 -5.04674674e-01  7.91509675e-01  3.46318978e-01
#   4.07422888e-01 -7.34767666e-01 -7.91672899e-01  4.46130463e-01
#   7.71869993e-01  7.73408691e-02  5.83877755e-01 -2.54783123e-01
#  -5.80063951e-01 -2.53401749e-01 -4.75769892e-01 -1.18267707e+00
#  -7.62222194e-01  1.05632006e+00  1.50601459e+00  9.32381471e-01
#  -1.33661072e-01  1.89057802e+00 -2.89475177e-01  3.47863812e-01
#  -1.99023678e+00  1.49644396e+00  1.04973312e+00  4.77276806e-01
#   1.05372786e+00  9.29193618e-01  1.13085447e+00  6.13002699e-02
#   5.36154331e-01  7.55916401e-01  1.00444136e+00 -7.72783296e-01
#   1.74669489e+00  1.12283074e+00 -1.61811390e-01  4.03060672e-01
#  -6.23055382e-02 -7.64467993e-01  9.11533972e-01 -3.15198377e+00
#   1.47072427e+00 -1.14056437e+00  4.26259015e-01  2.61731320e+00
#   1.73840152e+00 -7.27892727e-01  6.90427605e-01 -8.69216658e-01
#   7.78069661e-01 -3.67968098e-01  6.14111408e-01 -6.65613364e-02
#  -1.04774207e+00  1.89317439e-01 -9.63507534e-02 -2.54898787e+00
#   1.05243493e+00  1.95534533e-01 -1.82217570e-01  5.21655832e-01
#   7.64722430e-01 -6.93026044e-02  6.39143904e-02  2.49136943e+00
#  -7.73614212e-01  4.56761040e-01  2.18025108e-01  9.37068095e-01
#   9.09472412e-01  6.23351758e-01  9.43163091e-01 -7.25165431e-01
#   1.99630964e-01  8.24843627e-02 -3.13456261e-01 -7.42483122e-01
#   4.06937841e-01  2.49963975e+00 -1.09796720e+00  1.46120958e+00
#   7.42775318e-02 -7.98521206e-02 -1.27042799e+00  5.69772432e-01
#  -1.50303394e+00 -6.55695462e-01 -2.24637717e-01  1.11720716e+00
#   1.87646957e-02  7.03827642e-02 -1.91190260e-01  8.27136143e-01
#   6.90974492e-01 -4.00626236e-01  7.56018341e-01  1.18117711e+00
#   3.01850975e-01 -1.74290221e+00  4.32837664e-01  4.63778257e-01
#  -2.06738976e+00  2.08347022e+00  6.45529598e-02 -2.50223751e-01
#   1.99505872e-01  4.17823282e-02  1.84884819e+00  1.36797050e+00
#  -2.14311084e+00  3.91588971e-01 -1.55221669e-01  8.28903466e-01
#  -7.05922291e-01  5.70123917e-01 -8.25934263e-01  5.66005638e-01
#   2.64315087e-01 -1.48970933e+00  2.58466749e+00  3.78779453e-01
#  -6.27130028e-01 -6.72021277e-01  1.00808328e+00 -7.81727983e-01
#  -2.05882841e+00  2.62487244e-01  2.34178962e-01 -9.01937410e-02
#  -1.37493042e+00  1.24414774e+00  4.07729384e-01 -1.48138499e-01
#   9.16339433e-02  8.66723757e-01  6.41185460e-02  5.89309381e-01
#  -1.51510270e-01 -3.95958621e-01 -8.22565319e-01  2.37234949e-01
#  -7.12389112e-01  6.88248641e-03  1.98187141e+00 -1.96107457e-02
#   4.92351379e-01 -2.05592669e+00  1.30247061e+00 -7.16572575e-01
#  -1.45578329e+00  3.74392288e-01  1.57193844e+00  8.15645084e-01
#   1.28465309e+00  5.04865537e-02 -5.22582784e-01  2.83906771e-01
#  -7.12946892e-01 -1.90811662e-01 -4.37234497e-01 -4.69360715e-01]

# %% [markdown]
# ##Plotting
#
# We can use the plotting library we imported as follows.

# %%
mate.plot(X)

# %% [markdown]
# Ejemplo

# %%
mate.plot(Y)

# %% [markdown]
# ###Squelching Line Output
#
# You might have noticed the annoying line of the form `[<matplotlib.lines.Line2D at 0x7f72fdbc1710>]` before the plots. This is because the `.plot` function actually produces output. Sometimes we wish not to display output, we can accomplish this with the semi-colon as follows.

# %%
mate.plot(X);

# %% [markdown]
# Ejemplo

# %%
mate.plot(Y);

# %% [markdown]
# ###Adding Axis Labels
#
# No self-respecting quant leaves a graph without labeled axes. Here are some commands to help with that.

# %%
X = num.random.normal(0, 1, 1000)
X2 = num.random.normal(0, 1, 1000)

mate.plot(X);
mate.plot(X2);
mate.xlabel('Time') # The data we generated is unitless, but don't forget units in general.
mate.ylabel('Returns')
mate.legend(['X', 'X2']);

# %% [markdown]
# Ejemplo

# %%
X3 = num.random.normal(0, 1, 100)
X4 = num.random.normal(0, 1, 100)

mate.plot(X3);
mate.plot(X4);
mate.xlabel('Time') # The data we generated is unitless, but don't forget units in general.
mate.ylabel('Returns')
mate.legend(['X3', 'X4']);

# %% [markdown]
# ##Generating Statistics
#
# Let's use `numpy` to take some simple statistics.

# %%
num.mean(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-6f16c4b92409> in <module>()
# ----> 1 num.mean(X)
#
# NameError: name 'X' is not defined

# %%
num.std(X)
# Out:
# 0.9729339404798131

# %% [markdown]
# ##Getting Real Pricing Data
#
# Randomly sampled data can be great for testing ideas, but let's get some real data. We can use `get_pricing` to do that. You can use the `?` syntax as discussed above to get more information on `get_pricing`'s arguments.

# %%
data = get_pricing('MSFT', start_date='2020-3-4', end_date='2021-1-1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-44-5abb0340954b> in <module>()
# ----> 1 data = get_pricing('MSFT', start_date='2020-3-4', end_date='2021-1-1')
#
# NameError: name 'get_pricing' is not defined

# %% [markdown]
# Our data is now a dataframe. You can see the datetime index and the colums with different pricing data.

# %%
data1
# Out:
#            Date        Open        High  ...       Close   Adj Close    Volume
# 0    2020-02-04  177.139999  180.639999  ...  180.119995  177.822327  36433300
# 1    2020-02-05  184.029999  184.199997  ...  179.899994  177.605148  39186300
# 2    2020-02-06  180.970001  183.820007  ...  183.630005  181.287552  27751400
# 3    2020-02-07  182.850006  185.630005  ...  183.889999  181.544250  33529100
# 4    2020-02-10  183.580002  188.839996  ...  188.699997  186.292862  35844300
# ..          ...         ...         ...  ...         ...         ...       ...
# 266  2021-02-24  230.009995  235.199997  ...  234.550003  234.550003  26339700
# 267  2021-02-25  232.080002  234.589996  ...  228.990005  228.990005  39542200
# 268  2021-02-26  231.529999  235.369995  ...  232.380005  232.380005  37811200
# 269  2021-03-01  235.899994  237.470001  ...  236.940002  236.940002  25324000
# 270  2021-03-02  237.009995  237.300003  ...  233.869995  233.869995  22785500
#
# [271 rows x 7 columns]

# %% [markdown]
# This is a pandas dataframe, so we can index in to just get price like this. For more info on pandas, please [click here](http://pandas.pydata.org/pandas-docs/stable/10min.html).

# %%
X = data1['Volume']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-5b19625ddc91> in <module>()
# ----> 1 X = data1['Volume']
#
# NameError: name 'data1' is not defined

# %% [markdown]
# Because there is now also date information in our data, we provide two series to `.plot`. `X.index` gives us the datetime index, and `X.values` gives us the pricing values. These are used as the X and Y coordinates to make a graph.

# %%
mate.plot(X.index, X.values)
mate.ylabel('Volume')
mate.legend(['MSFT']);

# %% [markdown]
# We can get statistics again on real data.

# %%
num.mean(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c6fc2d041ebc> in <module>()
# ----> 1 num.mean(Y)
#
# NameError: name 'Y' is not defined

# %%
num.std(X)
# Out:
# 16632662.486028686

# %% [markdown]
# ##Getting Returns from Prices
#
# We can use the `pct_change` function to get returns. Notice how we drop the first element after doing this, as it will be `NaN` (nothing -> something results in a NaN percent change).

# %%
R = X.pct_change()[1:]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-72715ba92b1c> in <module>()
# ----> 1 R = X.pct_change()[1:]
#
# NameError: name 'X' is not defined

# %% [markdown]
# We can plot the returns distribution as a histogram.

# %%
mate.hist(R, bins=30)
mate.xlabel('Return')
mate.ylabel('Frequency')
mate.legend(['MSFT Returns']);

# %% [markdown]
# Get statistics again.

# %%
num.mean(R)
# Out:
# 0.03960801167684202

# %%
num.std(R)
# Out:
# 0.3085327264854655

# %% [markdown]
# Now let's go backwards and generate data out of a normal distribution using the statistics we estimated from Microsoft's returns. We'll see that we have good reason to suspect Microsoft's returns may not be normal, as the resulting normal distribution looks far different.

# %%
mate.hist(num.random.normal(num.mean(R), num.std(R), 10000), bins=30)
mate.xlabel('Return')
mate.ylabel('Frequency')
mate.legend(['Normally Distributed Returns']);

# %% [markdown]
# ##Generating a Moving Average
#
# `pandas` has some nice tools to allow us to generate rolling statistics. Here's an example. Notice how there's no moving average for the first 60 days, as we don't have 60 days of data on which to generate the statistic.

# %%
# Take the average of the last 60 days at each timepoint.
MAVG = pand.rolling_mean(X, window=30)
mate.plot(X.index, X.values)
mate.plot(MAVG.index, MAVG.values)
mate.ylabel('Volume')
mate.legend(['MSFT', '30-day MAVG']);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-71-d1a0848c3d03> in <module>()
#       1 # Take the average of the last 60 days at each timepoint.
# ----> 2 MAVG = pand.rolling_mean(X, window=30)
#       3 mate.plot(X.index, X.values)
#       4 mate.plot(MAVG.index, MAVG.values)
#       5 mate.ylabel('Volume')
#
# /usr/local/lib/python3.7/dist-packages/pandas/__init__.py in __getattr__(name)
#     256             return _SparseArray
#     257
# --> 258         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     259
#     260
#
# AttributeError: module 'pandas' has no attribute 'rolling_mean'

# %% [markdown]
# This presentation is for informational purposes only and does not constitute an offer to sell, a solicitation to buy, or a recommendation for any security; nor does it constitute an offer to provide investment advisory or other services by Quantopian, Inc. ("Quantopian"). Nothing contained herein constitutes investment advice or offers any opinion with respect to the suitability of any security, and any views expressed herein should not be taken as advice to buy, sell, or hold any security or as an endorsement of any security or company. In preparing the information contained herein, Quantopian, Inc. has not taken into account the investment needs, objectives, and financial circumstances of any particular investor. Any views expressed and data illustrated herein were prepared based upon information, believed to be reliable, available to Quantopian, Inc. at the time of publication. Quantopian makes no guarantees as to their accuracy or completeness. All information is subject to change and may quickly become unreliable for various reasons, including changes in market conditions or economic circumstances.
