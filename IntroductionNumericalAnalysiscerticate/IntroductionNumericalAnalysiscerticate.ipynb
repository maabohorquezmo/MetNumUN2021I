# %%
IntroductionNumericalAnalysis

# %% [markdown]
# ![certificatemetodos.png](data:image/png;base64,...)

# %% [markdown]
# Enlace Linkedin

# %% [markdown]
# https://www.coursera.org/account/accomplishments/verify/4N8NQSSAD997
